# %%
import nltk
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import string
import matplotlib.pyplot as plt
# %matplotlib inline
ps = nltk.PorterStemmer()
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
from collections import defaultdict
from string import punctuation
from heapq import nlargest
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/selma/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tweets=pd.read_csv('China_trade.csv', sep='\t')

# %%
tweets.head()
# Out:
#    Unnamed: 0  Favorite Count  Favorited                   ID  \
# 0           0               0      False  1170805357624606721
# 1           1               0      False  1170805351911972865
# 2           2               0      False  1170805320647622659
# 3           3               0      False  1170805315090210816
# 4           4               0      False  1170805305632002051
#
#             Phone Type       Replied  Retweet Count  Retweeted  \
# 0  Twitter for Android           NaN           1280      False
# 1   Twitter for iPhone           NaN           4791      False
# 2   Twitter for iPhone  1.170391e+18              0      False
# 3      Twitter Web App           NaN             13      False
# 4  Twitter for Android           NaN              6      False
#
#        Screen Name  Tweet Coordinates     Tweet Created At  \
# 0     vetch_tufted                NaN  2019-09-08 21:05:24
# 1  SpannaGattinara                NaN  2019-09-08 21:05:23
# 2   Winning_Gerald                NaN  2019-09-08 21:05:15
# 3    bissygumdrops                NaN  2019-09-08 21:05:14
# 4   NationMostXlnt                NaN  2019-09-08 21:05:12
#
#                                           Tweet Text  \
# 0  RT @JamesMelville: UK’s top trade partners (ex...
# 1  RT @MarkHertling: Im confused re the security ...
# 2  @AgnesNdiritu1 @VP @BorisJohnson Eu has no tra...
# 3  RT @RepublicanSwine: #TalibanTrump \n\nWay to ...
# 4  RT @HarmlessYardDog: Who started the trade war...
#
#               User Location      User Name
# 0  Scotland, United Kingdom   Tufted_Vetch
# 1      Kansas City, MO area         Spanna
# 2                       NaN     Gerald Lee
# 3                       NaN  Bissygumdrops
# 4               rural Ohio      Xlnt Eagle

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 14 columns):
# Unnamed: 0           2500 non-null int64
# Favorite Count       2500 non-null int64
# Favorited            2500 non-null bool
# ID                   2500 non-null int64
# Phone Type           2500 non-null object
# Replied              117 non-null float64
# Retweet Count        2500 non-null int64
# Retweeted            2500 non-null bool
# Screen Name          2500 non-null object
# Tweet Coordinates    0 non-null float64
# Tweet Created At     2500 non-null object
# Tweet Text           2500 non-null object
# User Location        1716 non-null object
# User Name            2499 non-null object
# dtypes: bool(2), float64(2), int64(4), object(6)
# memory usage: 239.3+ KB

# %% [markdown]
# # Sentiment analysis on raw data

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    return score['compound']

# %%
tweets['Polarity_score']=tweets['Tweet Text'].apply(sentiment_analyzer_scores)
tweets.head()
# Out:
#    Unnamed: 0  Favorite Count  Favorited                   ID  \
# 0           0               0      False  1170805357624606721
# 1           1               0      False  1170805351911972865
# 2           2               0      False  1170805320647622659
# 3           3               0      False  1170805315090210816
# 4           4               0      False  1170805305632002051
#
#             Phone Type       Replied  Retweet Count  Retweeted  \
# 0  Twitter for Android           NaN           1280      False
# 1   Twitter for iPhone           NaN           4791      False
# 2   Twitter for iPhone  1.170391e+18              0      False
# 3      Twitter Web App           NaN             13      False
# 4  Twitter for Android           NaN              6      False
#
#        Screen Name  Tweet Coordinates     Tweet Created At  \
# 0     vetch_tufted                NaN  2019-09-08 21:05:24
# 1  SpannaGattinara                NaN  2019-09-08 21:05:23
# 2   Winning_Gerald                NaN  2019-09-08 21:05:15
# 3    bissygumdrops                NaN  2019-09-08 21:05:14
# 4   NationMostXlnt                NaN  2019-09-08 21:05:12
#
#                                           Tweet Text  \
# 0  RT @JamesMelville: UK’s top trade partners (ex...
# 1  RT @MarkHertling: Im confused re the security ...
# 2  @AgnesNdiritu1 @VP @BorisJohnson Eu has no tra...
# 3  RT @RepublicanSwine: #TalibanTrump \n\nWay to ...
# 4  RT @HarmlessYardDog: Who started the trade war...
#
#               User Location      User Name  Polarity_score
# 0  Scotland, United Kingdom   Tufted_Vetch          0.7506
# 1      Kansas City, MO area         Spanna          0.0258
# 2                       NaN     Gerald Lee         -0.5994
# 3                       NaN  Bissygumdrops         -0.3182
# 4               rural Ohio      Xlnt Eagle         -0.7184

# %%
def Sentiment(score):
    if score>0:
        return 'Positive'
    if score<0:
        return 'Negative'
    return 'Neutral'

# %%
tweets['Sentiment']=tweets['Polarity_score'].apply(Sentiment)
tweets.head()
# Out:
#    Unnamed: 0  Favorite Count  Favorited                   ID  \
# 0           0               0      False  1170805357624606721
# 1           1               0      False  1170805351911972865
# 2           2               0      False  1170805320647622659
# 3           3               0      False  1170805315090210816
# 4           4               0      False  1170805305632002051
#
#             Phone Type       Replied  Retweet Count  Retweeted  \
# 0  Twitter for Android           NaN           1280      False
# 1   Twitter for iPhone           NaN           4791      False
# 2   Twitter for iPhone  1.170391e+18              0      False
# 3      Twitter Web App           NaN             13      False
# 4  Twitter for Android           NaN              6      False
#
#        Screen Name  Tweet Coordinates     Tweet Created At  \
# 0     vetch_tufted                NaN  2019-09-08 21:05:24
# 1  SpannaGattinara                NaN  2019-09-08 21:05:23
# 2   Winning_Gerald                NaN  2019-09-08 21:05:15
# 3    bissygumdrops                NaN  2019-09-08 21:05:14
# 4   NationMostXlnt                NaN  2019-09-08 21:05:12
#
#                                           Tweet Text  \
# 0  RT @JamesMelville: UK’s top trade partners (ex...
# 1  RT @MarkHertling: Im confused re the security ...
# 2  @AgnesNdiritu1 @VP @BorisJohnson Eu has no tra...
# 3  RT @RepublicanSwine: #TalibanTrump \n\nWay to ...
# 4  RT @HarmlessYardDog: Who started the trade war...
#
#               User Location      User Name  Polarity_score Sentiment
# 0  Scotland, United Kingdom   Tufted_Vetch          0.7506  Positive
# 1      Kansas City, MO area         Spanna          0.0258  Positive
# 2                       NaN     Gerald Lee         -0.5994  Negative
# 3                       NaN  Bissygumdrops         -0.3182  Negative
# 4               rural Ohio      Xlnt Eagle         -0.7184  Negative

# %%
tweets.Sentiment.value_counts().sort_values().plot(kind='barh')

# %%
tweets.loc[tweets.Sentiment=='Negative'].head()
# Out:
#     Unnamed: 0  Favorite Count  Favorited                   ID  \
# 2            2               0      False  1170805320647622659
# 3            3               0      False  1170805315090210816
# 4            4               0      False  1170805305632002051
# 7            7               0      False  1170805280772382721
# 10          10               0      False  1170805258743898112
#
#              Phone Type       Replied  Retweet Count  Retweeted  \
# 2    Twitter for iPhone  1.170391e+18              0      False
# 3       Twitter Web App           NaN             13      False
# 4   Twitter for Android           NaN              6      False
# 7       Twitter Web App           NaN            173      False
# 10      Twitter Web App           NaN             17      False
#
#        Screen Name  Tweet Coordinates     Tweet Created At  \
# 2   Winning_Gerald                NaN  2019-09-08 21:05:15
# 3    bissygumdrops                NaN  2019-09-08 21:05:14
# 4   NationMostXlnt                NaN  2019-09-08 21:05:12
# 7        trawetsla                NaN  2019-09-08 21:05:06
# 10      kriskoles1                NaN  2019-09-08 21:05:00
#
#                                            Tweet Text User Location  \
# 2   @AgnesNdiritu1 @VP @BorisJohnson Eu has no tra...           NaN
# 3   RT @RepublicanSwine: #TalibanTrump \n\nWay to ...           NaN
# 4   RT @HarmlessYardDog: Who started the trade war...   rural Ohio
# 7   RT @ResistanceNOW77: National Farmers Union VP...           NaN
# 10  RT @TheEconomist: China and America are locked...           NaN
#
#         User Name  Polarity_score Sentiment
# 2      Gerald Lee         -0.5994  Negative
# 3   Bissygumdrops         -0.3182  Negative
# 4      Xlnt Eagle         -0.7184  Negative
# 7      Al Stewart         -0.5994  Negative
# 10    Chris Coles         -0.4939  Negative

# %% [markdown]
# # Feature engeneering

# %%
# Number of words
tweets ['word_count']= tweets['Tweet Text'].apply(lambda x: len(str(x).split(" ")))
# Number of Characters 
tweets['char_count'] = tweets['Tweet Text'].str.len()
# average word length
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))

tweets['avg_word'] = tweets['Tweet Text'].apply(lambda x: avg_word(x))
# Count Stopwords
from nltk.corpus import stopwords
stop = stopwords.words('english')


tweets['stopwords_counts'] = tweets['Tweet Text'].apply(lambda x: len([x for x in x.split() if x in stop]))
tweets['hastags'] = tweets['Tweet Text'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
tweets['tags'] = tweets['Tweet Text'].apply(lambda x: len([x for x in x.split() if x.startswith('@')]))
tweets['numerics'] = tweets['Tweet Text'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))

# %% [markdown]
# # Clean tweet text to use in Machine learning

# %%
def clean_text(text):
    text = "".join([word.lower() for word in text if word not in string.punctuation])
    tokens = re.split('\W+', text)
    text = [ps.stem(word) for word in tokens if word not in stop]
    text= [word for word in text  if not word.startswith('#')]
    text=[word for word in text if not word.startswith ('@')]
    text=[word for word in text if word!='rt']
    return text

# %%
tweets['Clean_tweet_text']= tweets['Tweet Text'].apply(clean_text)

# %%
tweets['Clean_tweet_text'].head()
# Out:
# 0    [jamesmelvil, uk, top, trade, partner, export,...
# 1    [markhertl, im, confus, secur, strategi, leav,...
# 2    [agnesndiritu1, vp, borisjohnson, eu, trade, d...
# 3    [republicanswin, talibantrump, way, go, maga, ...
# 4    [harmlessyarddog, start, trade, war, china, th...
# Name: Clean_tweet_text, dtype: object

# %% [markdown]
# # TFIDF vector

# %%
tfidf_vect = TfidfVectorizer(analyzer=clean_text)
X_tfidf = tfidf_vect.fit_transform(tweets['Tweet Text'])

# %%
X_tfidf
# Out:
# <2500x2711 sparse matrix of type '<class 'numpy.float64'>'
# 	with 38944 stored elements in Compressed Sparse Row format>

# %%
X_features = pd.concat([tweets['word_count'], tweets['char_count'], tweets['avg_word'],tweets['stopwords_counts'], tweets['hastags'],tweets['tags'],tweets['numerics'],  
                        pd.DataFrame(X_tfidf.toarray())], axis=1)

# %%
X_features.shape
# Out:
# (2500, 2718)

# %%
from sklearn.decomposition import PCA

X_dense = X_tfidf.todense()
coords = PCA(n_components=2).fit_transform(X_dense)
plt.scatter(coords[:, 0], coords[:, 1], c='m')
plt.show()

# %% [markdown]
# # Clustering with Kmean

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
Sum_of_squared_distances = []
see=[]
for n in range (2,10):
    kmeans = KMeans(n_clusters=n, random_state=0).fit(X_features)
    y_pred = kmeans.predict(X_features)
    Sum_of_squared_distances.append(kmeans.inertia_)
    see.append([n, silhouette_score(X_features, kmeans.labels_)])

# %%
K=range(2,10)
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
see=pd.DataFrame(see)
plt.plot(see[0],see[1])
plt.title('Silhouette score Method For Optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette score Method For Optimal k')

# %% [markdown]
# both the Elbow method and the silhouette score methode sugest that the optimal k is 3

# %%
 kmeans = KMeans(n_clusters=3, random_state=0).fit(X_features)

# %%
tweets['cluster']=kmeans.fit_predict(X_features)

# %%
tweets['cluster'].value_counts()
# Out:
# 2    2208
# 0     196
# 1      96
# Name: cluster, dtype: int64

# %%
silhouette_score(X_features, kmeans.labels_)
# Out:
# 0.7844980385307165

# %% [markdown]
# # Word Clouds for each label

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import numpy as np

# %%
twitter_mask = np.array(Image.open( "./twitter.jpeg"))

# %%
stopwords = set(STOPWORDS)

# %%
wc = WordCloud(width = 2500,
    height = 2000,background_color="white", max_words=100, 
               stopwords=stopwords, contour_width=3, contour_color='steelblue')

# %%
for n in range (3):
    word_cluster=((tweets.loc[tweets['cluster']==n]['Clean_tweet_text']).apply(lambda x: " ".join (x))).values
    text=" ".join(word_cluster)
    wc.generate(text)
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.figure()
    #plt.title('Wordcloud of cluster "{}"'.format(n))
    plt.savefig('cluster{}.png'.format(n))
    #plt.imshow(twitter_mask, cmap=plt.cm.gray, interpolation='bilinear')
    #plt.axis("off")
    plt.show()

# %% [markdown]
# # extract most important words in each cluster

# %%
# combine text for each cluster
text={}
for i,cluster in enumerate(tweets['cluster']):
    OneCluster = tweets['Tweet Text'][i]
    if cluster not in text.keys():
        text[cluster] = OneCluster
    else:
        text[cluster] += str(OneCluster)

# %%
#extract keywords from each cluster
keywords = {}
counts={}
for cluster in range(3):
    word_sent = word_tokenize(text[cluster].lower())
    word_sent=[word for word in word_sent if word not in stop]
    freq = FreqDist(word_sent)
    keywords[cluster] = nlargest(100, freq, key=freq.get)
    counts[cluster]=freq

# %%
# extract keywords
unique_keys={}
for cluster in range(3):   
    other_clusters=list(set(range(3))-set([cluster]))
    keys_other_clusters=set(keywords[other_clusters[0]]).union(set(keywords[other_clusters[1]]))
    unique=set(keywords[cluster])-keys_other_clusters
    unique_keys[cluster]=nlargest(10, unique, key=counts[cluster].get)

# %%
print(unique_keys)
# Out:
# {0: ['fell', '16', 'unseen1_unseen', 'hmmmm', '//t.co/cre9hewlpsrt', 'business', 'sales', 'hurting', 'shrink', "n't"], 1: ['//t.co/k0sf9hh3mw', '//t.co/k0sf9hprym', 'reuterscn', '分析师观点：中国8月出口重回负增长', '”', 'u.s', '外需疲弱抢出口提振不明显', 'dollars.', 'winning', 'flee'], 2: ['$', 'states', 'united', 'kong', 'hong', '🇨🇳', 'jamesmelville', 'uk', '🇺🇸', '2018']}

# %% [markdown]
# # KNN Clustering

# %%
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
X_train, X_test, y_train, y_test= train_test_split(X_features , tweets['cluster'], test_size=0.3)

# %%
for n in range (3,11, 2):
    knn= KNeighborsClassifier(n_neighbors=n)
    knn.fit(X_train, y_train)
    y_pred=knn.predict(X_test)
    print ('For n=', n)
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test,y_pred))
    print('******************************')
# Out:
# For n= 3
# [[ 68   0   0]
#  [  0  22   0]
#  [  0   0 660]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        68
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00       660
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
#
# ******************************
# For n= 5
# [[ 68   0   0]
#  [  0  22   0]
#  [  0   0 660]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        68
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00       660
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
#
# ******************************
# For n= 7
# [[ 68   0   0]
#  [  0  22   0]
#  [  0   0 660]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        68
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00       660
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
#
# ******************************
# For n= 9
# [[ 68   0   0]
#  [  0  22   0]
#  [  0   0 660]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        68
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00       660
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
#
# ******************************
